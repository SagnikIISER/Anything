# %%
dir="c:\\Users\\Ritam\\Desktop\\Measurement Induced Phase Transition\\NISQcodes\\Julia\\";

include(dir*"Header.jl")
# Out:
# (process:28736): GLib-GIO-WARNING **: 20:45:09.196: Unexpectedly, UWP app `KDEe.V.Okular_22.801.1132.0_x64__7vt06qxq7ptv8' (AUMId `KDEe.V.Okular_7vt06qxq7ptv8!KDEe.V.Okular') supports 5 extensions but has no verbs
# WARNING: using ITensors.dir in module Main conflicts with an existing identifier.

# %%
N=100                       # Number of sites
sites =siteinds("S=1", N);  #Tells to create array of S=1 particles. Local dim 3 preloaded
                            # Only works with S=1/2, 1
# Out:
# 100-element Vector{Index{Int64}}:
#  (dim=3|id=265|"S=1,Site,n=1")
#  (dim=3|id=89|"S=1,Site,n=2")
#  (dim=3|id=683|"S=1,Site,n=3")
#  (dim=3|id=168|"S=1,Site,n=4")
#  (dim=3|id=45|"S=1,Site,n=5")
#  (dim=3|id=93|"S=1,Site,n=6")
#  (dim=3|id=694|"S=1,Site,n=7")
#  (dim=3|id=772|"S=1,Site,n=8")
#  (dim=3|id=734|"S=1,Site,n=9")
#  (dim=3|id=485|"S=1,Site,n=10")
#  (dim=3|id=746|"S=1,Site,n=11")
#  (dim=3|id=203|"S=1,Site,n=12")
#  (dim=3|id=4|"S=1,Site,n=13")
#  ⋮
#  (dim=3|id=103|"S=1,Site,n=89")
#  (dim=3|id=242|"S=1,Site,n=90")
#  (dim=3|id=141|"S=1,Site,n=91")
#  (dim=3|id=928|"S=1,Site,n=92")
#  (dim=3|id=960|"S=1,Site,n=93")
#  (dim=3|id=766|"S=1,Site,n=94")
#  (dim=3|id=27|"S=1,Site,n=95")
#  (dim=3|id=989|"S=1,Site,n=96")
#  (dim=3|id=951|"S=1,Site,n=97")
#  (dim=3|id=684|"S=1,Site,n=98")
#  (dim=3|id=107|"S=1,Site,n=99")
#  (dim=3|id=937|"S=1,Site,n=100")

# %%
Using ITensors
# Out:
# syntax: extra token "ITensors" after end of expression
#
# Stacktrace:
#  [1] top-level scope
#    @ In[1]:1
#  [2] eval
#    @ .\boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1196
