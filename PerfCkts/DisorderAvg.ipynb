# %%
#Global Header File

using LinearAlgebra             #   Linear Algebra 
using Kronecker                 #   For Kronecker Product 
using MKL                       #   MKL
using Plots, PyPlot             #   Plot Modules
using Random, Distributions     #   Random RandomMatrices
using RandomMatrices            #   Random Matrtices
using CSV, DelimitedFiles       #   File Management stuff
using DataFrames                #   File Management 
using ITensors
#using ITensorsVisualization     #   Packages for ITensors

# %%
ordpar=fill(0.0,51);
thetamean=0.0;

for Itr in 1:100 
    ordpar1=readdlm("e:\\Data\\ModelZ\\L8\\Ordpar_theta_$(thetamean)_Itr_$(Itr).csv",',',Float64);
    ordpar=ordpar+ordpar1;
end

ordparnew=ordpar/101;

# %%
Ordpar1 = readdlm("e:\\Data\\Vedika\\L8\\Ordpar_theta_0.0_Itr_1.csv",',',Float64);

# %%
ordpar
# Out:
# 51×1 Matrix{Float64}:
#  36.71613444934394
#  38.53368635600727
#  40.20381353787553
#  39.38178933492148
#  38.68795853057328
#  39.26716097361695
#  38.997913769926555
#  38.74826843694617
#  39.43265847332443
#  40.16841953004739
#  40.991373026684315
#  40.935090896234584
#  41.17773641160281
#   ⋮
#  40.2366310418326
#  40.04875832304899
#  40.003759270773436
#  40.04703925492087
#  39.43590939315663
#  39.76700046626411
#  39.64920204725215
#  39.16225089311527
#  38.88319858709998
#  39.2706082273171
#  38.713815720933646
#  38.45349997567671

# %%
xax=1:51
Plots.plot(xax,ordpar)

# %%
xax=1:51
Plots.plot(xax,ordpar)
