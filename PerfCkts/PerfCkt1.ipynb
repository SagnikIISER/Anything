# %%
dir="c:\\Users\\Ritam\\Desktop\\Measurement Induced Phase Transition\\NISQcodes\\Julia\\";

include(dir*"Header.jl")
include(dir*"Gates.jl")
include(dir*"TransferMat.jl")
# Out:
# (process:3920): GLib-GIO-WARNING **: 21:22:18.888: Unexpectedly, UWP app `KDEe.V.Okular_22.801.1132.0_x64__7vt06qxq7ptv8' (AUMId `KDEe.V.Okular_7vt06qxq7ptv8!KDEe.V.Okular') supports 5 extensions but has no verbs
# WARNING: using ITensors.dir in module Main conflicts with an existing identifier.

# %%
#Attempting to compute a circuit perforated at Random space time points

p=0.5;          #Measuring Probability

if rand(1)[1]<p
    print("gay")

    else
        print("no")
end
# Out:
# gay
