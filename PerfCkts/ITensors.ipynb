# %%
dir="c:\\Users\\Ritam\\Desktop\\Measurement Induced Phase Transition\\NISQcodes\\Julia\\";

include(dir*"Header.jl")
#include(dir*"Gates.jl")
include(dir*"TransferMat.jl")
# Out:
# (process:28576): GLib-GIO-WARNING **: 18:15:08.933: Unexpectedly, UWP app `KDEe.V.Okular_22.801.1132.0_x64__7vt06qxq7ptv8' (AUMId `KDEe.V.Okular_7vt06qxq7ptv8!KDEe.V.Okular') supports 5 extensions but has no verbs
# WARNING: using ITensors.dir in module Main conflicts with an existing identifier.

# %%
i=Index(3,"index_i");
j=Index(2,"index_j");
k=Index(4,"index_k");

T=ITensor(i,j,k)
# Out:
# ITensor ord=3 (dim=3|id=673|"index_i") (dim=2|id=707|"index_j") (dim=4|id=842|"index_k")
# NDTensors.Dense{Float64, Vector{Float64}}

# %%
l=Index(2,"index_l");
m=Index(4,"index_m");

S=ITensor(i,l,m)
# Out:
# ITensor ord=3 (dim=3|id=673|"index_i") (dim=2|id=291|"index_l") (dim=4|id=340|"index_m")
# NDTensors.Dense{Float64, Vector{Float64}}

# %%
T*S
# Out:
# ITensor ord=4 (dim=2|id=707|"index_j") (dim=4|id=842|"index_k") (dim=2|id=291|"index_l") (dim=4|id=340|"index_m")
# NDTensors.Dense{Float64, Vector{Float64}}

# %%
TS=@visualize T*S
# Out:
# ┌ Info: Makie/AbstractPlotting is caching fonts, this may take a while. Needed only on first run!
# └ @ AbstractPlotting C:\Users\Ritam\.julia\packages\AbstractPlotting\gE7AT\src\utilities\texture_atlas.jl:115
# ITensor ord=4 (dim=2|id=707|"index_j") (dim=4|id=842|"index_k") (dim=2|id=291|"index_l") (dim=4|id=340|"index_m")
# NDTensors.Dense{Float64, Vector{Float64}}

# %%
@visualize T*S*T
# Out:
# ITensor ord=3 (dim=2|id=291|"index_l") (dim=4|id=340|"index_m") (dim=3|id=673|"index_i")
# NDTensors.Dense{Float64, Vector{Float64}}

# %%
# Out:
# LoadError: type Symbol has no field args
# in expression starting at In[13]:1
#
# Stacktrace:
#  [1] getproperty(x::Symbol, f::Symbol)
#    @ Base .\Base.jl:42
#  [2] var"@visualize"(__source__::LineNumberNode, __module__::Module, ex::Any, kwargs::Vararg{Any})
#    @ ITensorsVisualization C:\Users\Ritam\.julia\packages\ITensorsVisualization\RtaL7\src\visualize_macro.jl:70
#  [3] eval
#    @ .\boot.jl:373 [inlined]
#  [4] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1196
