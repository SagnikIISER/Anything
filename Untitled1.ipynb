# %%
using LinearAlgebra 
using Kronecker
using Plots, PyPlot
using Random, Distributions
using RandomMatrices
# Out:
# (process:21744): GLib-GIO-WARNING **: 14:01:53.733: Unexpectedly, UWP app `KDEe.V.Okular_22.801.1132.0_x64__7vt06qxq7ptv8' (AUMId `KDEe.V.Okular_7vt06qxq7ptv8!KDEe.V.Okular') supports 5 extensions but has no verbs

# %%
GaussianHermiteMatrix(4,2)
# Out:
# UndefVarError: GaussianHermiteMatrix not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[2]:1
#  [2] eval
#    @ .\boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1196
